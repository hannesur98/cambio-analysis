# %%
from cambio.methods_prs import PRSConfig, ComplementPRS
import pandas as pd
locus_cols = {
    "CFH_A": "C___8355565_10",
    "CFH_B": "C___2530278_10",
    "C3":    "C__26330755_10",
    "CFI":   "C__34681305_20",
    "ARMS2": "C__29934973_20",
}
cfg = PRSConfig(risk_alleles={"CFH_A":"T","CFH_B":"A","C3":"C","CFI":"C","ARMS2":"T"})

prs = ComplementPRS(
    data="/Users/hannes/Documents/cambio-analysis/2025_07_24_CAMBio_Tabelle_für_Hannes_Urbat.csv",
    locus_cols=locus_cols,
    config=cfg,
    id_col="Alias",
    aggregate=True,         # pro Patient zusammenfassen
    missing="zero",         # fehlende Marker als 0 zählen (pragmatisch)
    normalize=False         # optional True: durch #beobachteter Marker teilen
)
prs_patients = prs.compute_patientlevel()
prs_patients.head()
# Out:
#   Alias C___8355565_10 C___2530278_10 C__26330755_10 C__34681305_20  \
# 0     1             CT              C              G              C
# 1    10             CT             AC              G              T
# 2   100            NaN            NaN            NaN            NaN
# 3   101            NaN            NaN            NaN            NaN
# 4   102            NaN            NaN            NaN            NaN
#
#   C__29934973_20  CFH_A_riskcount  CFH_B_riskcount  C3_riskcount  \
# 0             GT              1.0              NaN           NaN
# 1             GT              1.0              1.0           NaN
# 2            NaN              NaN              NaN           NaN
# 3            NaN              NaN              NaN           NaN
# 4            NaN              NaN              NaN           NaN
#
#    CFI_riskcount  ARMS2_riskcount  n_observed_markers  pPRS_raw    pPRS_z  \
# 0            NaN              1.0                   2       2.0 -0.025613
# 1            NaN              1.0                   3       3.0  0.794002
# 2            NaN              NaN                   0       0.0 -1.664843
# 3            NaN              NaN                   0       0.0 -1.664843
# 4            NaN              NaN                   0       0.0 -1.664843
#
#    pPRS_quintile
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
prs_patients["Alias_num"] = pd.to_numeric(prs_patients["Alias"], errors="coerce")
prs_patients = prs_patients.sort_values(["Alias_num","Alias"], na_position="last").drop(columns="Alias_num")
prs_patients.head(10)
# Out:
#    Alias C___8355565_10 C___2530278_10 C__26330755_10 C__34681305_20  \
# 0      1             CT              C              G              C
# 13     2              T             AC              C             TC
# 23     3             CT             AC              G              C
# 44     5            NaN            NaN            NaN            NaN
# 54     6              C              C              G              C
# 64     7              T              A              G              C
# 75     8              T             AC             CG              C
# 85     9              C              C             CG              T
# 1     10             CT             AC              G              T
# 5     11             CT             AC             CG              C
#
#    C__29934973_20  CFH_A_riskcount  CFH_B_riskcount  C3_riskcount  \
# 0              GT              1.0              NaN           NaN
# 13              G              NaN              1.0           NaN
# 23              G              1.0              1.0           NaN
# 44            NaN              NaN              NaN           NaN
# 54              G              NaN              NaN           NaN
# 64             GT              NaN              NaN           NaN
# 75              G              NaN              1.0           1.0
# 85             GT              NaN              NaN           1.0
# 1              GT              1.0              1.0           NaN
# 5               G              1.0              1.0           1.0
#
#     CFI_riskcount  ARMS2_riskcount  n_observed_markers  pPRS_raw    pPRS_z  \
# 0             NaN              1.0                   2       2.0 -0.025613
# 13            1.0              NaN                   2       2.0 -0.025613
# 23            NaN              NaN                   2       2.0 -0.025613
# 44            NaN              NaN                   0       0.0 -1.664843
# 54            NaN              NaN                   0       0.0 -1.664843
# 64            NaN              1.0                   1       1.0 -0.845228
# 75            NaN              NaN                   2       2.0 -0.025613
# 85            NaN              1.0                   2       2.0 -0.025613
# 1             NaN              1.0                   3       3.0  0.794002
# 5             NaN              NaN                   3       3.0  0.794002
#
#     pPRS_quintile
# 0             NaN
# 13            NaN
# 23            NaN
# 44            NaN
# 54            NaN
# 64            NaN
# 75            NaN
# 85            NaN
# 1             NaN
# 5             NaN

# %%
cols = [c for c in prs_patients.columns if c.endswith("_riskcount")] + ["n_observed_markers","pPRS_raw","pPRS_z","pPRS_quintile"]
prs_patients[cols].head()
# Out:
#    CFH_A_riskcount  CFH_B_riskcount  C3_riskcount  CFI_riskcount  \
# 0              1.0              NaN           NaN            NaN
# 1              1.0              1.0           NaN            NaN
# 2              NaN              NaN           NaN            NaN
# 3              NaN              NaN           NaN            NaN
# 4              NaN              NaN           NaN            NaN
#
#    ARMS2_riskcount  n_observed_markers  pPRS_raw    pPRS_z  pPRS_quintile
# 0              1.0                   2       2.0 -0.025613            NaN
# 1              1.0                   3       3.0  0.794002            NaN
# 2              NaN                   0       0.0 -1.664843            NaN
# 3              NaN                   0       0.0 -1.664843            NaN
# 4              NaN                   0       0.0 -1.664843            NaN

# %%
for c in [x for x in prs_patients.columns if x.endswith("_riskcount")]:
    print("\n", c)
    print(prs_patients[c].value_counts(dropna=False))
print("\nAnteil fehlend pro Marker:")
print(prs_patients[[x for x in prs_patients.columns if x.endswith("_riskcount")]].isna().mean().round(3))
# Out:
#  CFH_A_riskcount
# CFH_A_riskcount
# NaN    54
# 1.0    42
# Name: count, dtype: int64
#
#  CFH_B_riskcount
# CFH_B_riskcount
# 1.0    48
# NaN    47
# 0.0     1
# Name: count, dtype: int64
#
#  C3_riskcount
# C3_riskcount
# NaN    53
# 1.0    43
# Name: count, dtype: int64
#
#  CFI_riskcount
# CFI_riskcount
# NaN    59
# 1.0    35
# 0.0     2
# Name: count, dtype: int64
#
#  ARMS2_riskcount
# ARMS2_riskcount
# NaN    68
# 1.0    27
# 0.0     1
# Name: count, dtype: int64
#
# Anteil fehlend pro Marker:
# CFH_A_riskcount    0.562
# CFH_B_riskcount    0.490
# C3_riskcount       0.552
# CFI_riskcount      0.615
# ARMS2_riskcount    0.708
# dtype: float64

# %%
# einen Alias zum Prüfen auswählen (z.B. 1 oder 102)
aid = "25"  # anpassen

locus_cols = {
    "CFH_A": "C___8355565_10",
    "CFH_B": "C___2530278_10",
    "C3":    "C__26330755_10",
    "CFI":   "C__34681305_20",
    "ARMS2": "C__29934973_20",
}

risk_cols = [f"{m}_riskcount" for m in locus_cols]
orig_cols = list(locus_cols.values())

row = prs_patients.loc[prs_patients["Alias"] == aid, orig_cols + risk_cols + ["pPRS_raw","n_observed_markers"]]
row.T  # transponiert anzeigen
# Out:
#                      19
# C___8355565_10        T
# C___2530278_10        A
# C__26330755_10       CG
# C__34681305_20       TC
# C__29934973_20      NaN
# CFH_A_riskcount     NaN
# CFH_B_riskcount     NaN
# C3_riskcount        1.0
# CFI_riskcount       1.0
# ARMS2_riskcount     NaN
# pPRS_raw            2.0
# n_observed_markers    2
